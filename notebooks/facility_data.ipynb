# %% [markdown]
# # Fetching Facility Data
#
# Reverse engineering Yale's energy usage website

# %%
import json
import re

import polars as pl
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get("https://java.facilities.yale.edu/energy/")

# %%
soup = BeautifulSoup(response.text, "html.parser")

script_text = soup.find("script", string=re.compile("var user")).string

# extract JSON parts
user_json = re.search(r'var user\s*=\s*(\{.*?\});', script_text, re.S).group(1)
buildings_json = re.search(r'var buildings\s*=\s*(\[.*?\]);', script_text, re.S).group(1)

user = json.loads(user_json)
buildings = json.loads(buildings_json)

print(user)
print(buildings)
# Out:
# {'sets': [{'bsID': 1, 'bsName': 'Custom', 'bsDescription': 'Custom', 'bsPublic': 0, 'owner': 'unk', 'sort': 0, 'buildings': []}, {'bsID': 20, 'bsName': 'Power Plants', 'bsPublic': 1, 'owner': 'sa', 'sort': 60, 'buildings': [{'site': 'CEN', 'facid': '1425', 'name': 'CENTRAL POWER PLANT', 'address': 'TOWER PARKWAY,120', 'searchable': '1425 CENTRAL POWER PLANT CPP CPP CENTRAL POWER PLANT TOWER PKWY, 120', 'zone': 'ZONE 4', 'owned': 'OO', 'status': 'OPEN', 'latitude': 41.313039, 'longitude': -72.928887}, {'site': 'MED', 'facid': '3160', 'name': 'STERLING POWER PLANT', 'address': 'CONGRESS AVENUE, 309', 'searchable': '3160 STERLING POWER PLANT SPP SPP STERLING POWER PLANT CONGRESS AVE, 309', 'zone': 'MEDICAL', 'owned': 'OO', 'status': 'OPEN', 'latitude': 41.30302, 'longitude': -72.932705}, {'site': 'WST', 'facid': '4230', 'name': 'WC POWER PLANT', 'address': 'WEST CAMPUS DRIVE, 700', 'searchable': '4230 WC POWER PLANT W-PWRPL W-PWRPL WC POWER PLANT W CAMPUS DR, 700', 'owned': 'OO', 'status': 'OPEN', 'latitude': 41.256255, 'longitude': -72.988228}]}, {'bsID': 3, 'bsName': 'Served By CPP', 'bsPublic': 1, 'owner': 'sa', 'sort': 60, 'buildings': [{'site': 'CEN', 'facid': '1530', 'name': 'A.K. WATSON HALL', 'address': 'PROSPECT STREET,  51', 'searchable': '1530 A.K. WATSON HALL AKW AKW WATSON HALL, ARTHUR K. PROSPECT ST,  51', 'zone': 'ZONE 2', 'owned': 'OO', 'status': 'OPEN', 'latitude': 41.313064, 'longitude': -72.924933}, {'site': 'CEN', 'facid': '1125', 'name': 'ALLWIN HALL', 'address': 'HILLHOUSE AVENUE, 31', 'searchable': '1125 ALLWIN HALL ALW ALW ALLWIN HALL HILLHOUSE AVE, 31', 'zone': 'ZONE 2', 'owned': 'OO', 'status': 'OPEN', 'latitude': 41.313919, 'longitude': -72.923116}, {'site': 'CEN', 'facid': '2403', 'name': 'ARNOLD HALL', 'address': 'ELM STREET, 304', 'searchable': '2403 ARNOLD HALL ARN ARN ROBERT M. ARNOLD HALL ELM ST, 304', 'zone': 'ZONE 4', 'owned': 'OM', 'status': 'OPEN', 'latitude': 41.311041, 'longitude': -72.93145}, {'site': 'CEN', 'facid': '1413', 'name': 'BAKER HALL', 'address': 'TOWER PARKWAY,100', 'searchable': '1413 BAKER HALL BAKER BAKER ROBERT C & CHRISTINA BAKER HALL AT YALE LAW SCHOOL TOWER PKWY,100', 'zone': 'ZONE 4', 'owned': 'OO', 'status': 'OPEN', 'latitude': 41.313749, 'longitude': -72.929123}, {'site': 'CEN', 'facid': '1030', 'name': 'B
# %%
rows = []

for s in user["sets"]:
    set_meta = {
        "bsID": s["bsID"],
        "bsName": s["bsName"],
        "bsDescription": s.get("bsDescription"),
        "bsPublic": s["bsPublic"],
        "owner": s["owner"],
        "sort": s["sort"]
    }

    for b in s["buildings"]:
        row = {**set_meta, **b}
        rows.append(row)

df = pl.DataFrame(rows)

# %%
facilities = (
    df
    .unique(subset=["facid"])
    .select([
        "facid",
        "site",
        "name",
        "address",
        "zone",
        "owned",
        "status",
        "latitude",
        "longitude"
    ])
    .sort("facid")
)
building_sets = (
    df
    .unique(subset=["bsID"])
    .select([
        "bsID",
        "bsName",
        "bsDescription",
        "bsPublic",
        "owner",
        "sort"
    ])
    .sort("bsID")
)
membership = (
    df
    .select(["facid", "bsID"])
    .unique()
    .sort(["facid", "bsID"])
)

# %%
facilities
# Out:
# shape: (370, 9)
# ┌───────┬──────┬──────────────────┬──────────────────┬───┬───────┬────────┬───────────┬────────────┐
# │ facid ┆ site ┆ name             ┆ address          ┆ … ┆ owned ┆ status ┆ latitude  ┆ longitude  │
# │ ---   ┆ ---  ┆ ---              ┆ ---              ┆   ┆ ---   ┆ ---    ┆ ---       ┆ ---        │
# │ str   ┆ str  ┆ str              ┆ str              ┆   ┆ str   ┆ str    ┆ f64       ┆ f64        │
# ╞═══════╪══════╪══════════════════╪══════════════════╪═══╪═══════╪════════╪═══════════╪════════════╡
# │ 0000  ┆ CEN  ┆ FAC ID-NON-BLDG  ┆ NOT APPLICABLE   ┆ … ┆ null  ┆ OPEN   ┆ null      ┆ null       │
# │       ┆      ┆ ORGS             ┆                  ┆   ┆       ┆        ┆           ┆            │
# │ 0110  ┆ CEN  ┆ CALVIN HILL DAY  ┆ HIGHLAND STREET, ┆ … ┆ OO    ┆ OPEN   ┆ 41.328181 ┆ -72.920866 │
# │       ┆      ┆ CARE             ┆ 150              ┆   ┆       ┆        ┆           ┆            │
# │ 0120  ┆ CEN  ┆ WHITEHALL APTS   ┆ CANNER STREET,   ┆ … ┆ OO    ┆ OPEN   ┆ 41.325814 ┆ -72.921398 │
# │       ┆      ┆ 375-385          ┆ 375-385          ┆   ┆       ┆        ┆           ┆            │
# │ 0122  ┆ CEN  ┆ WHITEHALL APTS   ┆ CANNER STREET,   ┆ … ┆ OO    ┆ OPEN   ┆ 41.326013 ┆ -72.922116 │
# │       ┆      ┆ 405-407          ┆ 405-407          ┆   ┆       ┆        ┆           ┆            │
# │ 0124  ┆ CEN  ┆ WHITEHALL APTS   ┆ PROSPECT STREET, ┆ … ┆ OO    ┆ OPEN   ┆ 41.326293 ┆ -72.921995 │
# │       ┆      ┆ 511-521          ┆ 511-521          ┆   ┆       ┆        ┆           ┆            │
# │ …     ┆ …    ┆ …                ┆ …                ┆ … ┆ …     ┆ …      ┆ …         ┆ …          │
# │ 4245  ┆ WST  ┆ WC ENERGY        ┆ WEST CAMPUS      ┆ … ┆ OO    ┆ OPEN   ┆ 41.258284 ┆ -72.990042 │
# │       ┆      ┆ SCIENCES CTR     ┆ DRIVE, 520       ┆   ┆       ┆        ┆           ┆            │
# │ 4250  ┆ WST  ┆ WC COLLECTION ST ┆ WEST CAMPUS      ┆ … ┆ OO    ┆ OPEN   ┆ 41.259342 ┆ -72.987395 │
# │       ┆      ┆ CTR              ┆ DRIVE, 900       ┆   ┆       ┆        ┆           ┆            │
# │ 4270  ┆ WST  ┆ WC STORAGE &     ┆ WEST CAMPUS      ┆ … ┆ OO    ┆ OPEN   ┆ 41.257826 ┆ -72.985888 │
# │       ┆      ┆ RECEIV CTR       ┆ DRIVE, 750       ┆   ┆       ┆        ┆           ┆            │
# │ 4272  ┆ WST  ┆ WC ENVIR HL &    ┆ WEST CAMPUS      ┆ … ┆ OO    ┆ OPEN   ┆ 41.256759 ┆ -72.987472 │
# │       ┆      ┆ SFTY STOR        ┆ DRIVE, 720       ┆   ┆       ┆        ┆           ┆            │
# │ 4700  ┆ USA  ┆ YALE-TOUMEY      ┆ KEENE ROAD       ┆ … ┆ OO    ┆ OPEN   ┆ 42.838851 ┆ -72.351937 │
# │       ┆      ┆ FOREST           ┆                  ┆   ┆       ┆        ┆           ┆            │
# └───────┴──────┴──────────────────┴──────────────────┴───┴───────┴────────┴───────────┴────────────┘

# %%
building_sets
# Out:
# shape: (16, 6)
# ┌──────┬───────────────────────────┬───────────────┬──────────┬───────┬──────┐
# │ bsID ┆ bsName                    ┆ bsDescription ┆ bsPublic ┆ owner ┆ sort │
# │ ---  ┆ ---                       ┆ ---           ┆ ---      ┆ ---   ┆ ---  │
# │ i64  ┆ str                       ┆ null          ┆ i64      ┆ str   ┆ i64  │
# ╞══════╪═══════════════════════════╪═══════════════╪══════════╪═══════╪══════╡
# │ 2    ┆ Served By SPP             ┆ null          ┆ 1        ┆ sa    ┆ 60   │
# │ 3    ┆ Served By CPP             ┆ null          ┆ 1        ┆ sa    ┆ 60   │
# │ 4    ┆ Served By WPP             ┆ null          ┆ 1        ┆ sa    ┆ 60   │
# │ 5    ┆ Served By CPP or SPP      ┆ null          ┆ 1        ┆ sa    ┆ 60   │
# │ 20   ┆ Power Plants              ┆ null          ┆ 1        ┆ sa    ┆ 60   │
# │ …    ┆ …                         ┆ …             ┆ …        ┆ …     ┆ …    │
# │ 55   ┆ Academic & Admin: Small   ┆ null          ┆ 1        ┆ sa    ┆ 70   │
# │ 56   ┆ YSM Laboratories          ┆ null          ┆ 1        ┆ sa    ┆ 70   │
# │ 57   ┆ YSM Non Laboratories      ┆ null          ┆ 1        ┆ sa    ┆ 70   │
# │ 58   ┆ West Campus               ┆ null          ┆ 1        ┆ sa    ┆ 70   │
# │ 59   ┆ Not Served by Yale Plants ┆ null          ┆ 1        ┆ sa    ┆ 61   │
# └──────┴───────────────────────────┴───────────────┴──────────┴───────┴──────┘

# %%
membership
# Out:
# shape: (975, 2)
# ┌───────┬──────┐
# │ facid ┆ bsID │
# │ ---   ┆ ---  │
# │ str   ┆ i64  │
# ╞═══════╪══════╡
# │ 0000  ┆ 59   │
# │ 0110  ┆ 59   │
# │ 0120  ┆ 59   │
# │ 0122  ┆ 59   │
# │ 0124  ┆ 59   │
# │ …     ┆ …    │
# │ 4270  ┆ 58   │
# │ 4272  ┆ 4    │
# │ 4272  ┆ 21   │
# │ 4272  ┆ 58   │
# │ 4700  ┆ 59   │
# └───────┴──────┘

# %%
# Save to CSV
facilities.write_csv("../data/raw/facilities.csv")
building_sets.write_csv("../data/raw/building_sets.csv")
membership.write_csv("../data/raw/membership.csv")
